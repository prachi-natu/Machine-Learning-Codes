# %% [markdown]
# ### <center>Machine Learning </center>
# ### <center>Experiment No. 02: Data Visualization using Matplotlib and Seaborn</center>

# %% [markdown]
# **Aim:** To Explore Data Visualization using Matplotlib and Seaborn Library<br>
# **Prerequisites:** Basic Data structures in python like list, tuple, dictionaary and control structures in python<br>
# **Outcomes:** After completion of this experiment students will be able to:
#               1. Visualize and understand data from different perspectives using Matplotlib and Seaborn
#               2. Plot different plots like Scatterplot, Histogram Barplot

# %% [markdown]
# ### Theory and Sample Code:
#
# ### Data Visualization:
# The fastest way to learn more about your data is to use data visualization. We need data visualization because a visual summary of information makes it easier to identify patterns and trends than looking through thousands of rows on a spreadsheet. It's the way the human brain works.Charts and graphs make communicating data findings easier even if you can identify the patterns without them. A good visualization should establish two aspects of the data being presented: Show connections within the data that are too complex to explain with words. Make it easier for the audience to quickly understand the information presented and consider the outcomes from that data.<br>
# **Note:** It is Mandatory for students to explore in detail documentation of each command used in this Lab Manual on Numpy and Pandas documentation website.
#
# ### Matplotlib:
# Matplotlib is one of the most popular Python packages used for data visualization. It is a cross-platform library for making 2D plots from data in arrays. It provides an object-oriented API that helps in embedding plots in applications using Python GUI toolkits such as PyQt, WxPythonotTkinter. It can be used in Python and IPython shells, Jupyter notebook and web application servers also. Matplotlib is written in Python and makes use of NumPy, the numerical mathematics extension of Python.
# Matlab can be installed using **pip install matlab** command
#
# matplotlib.pyplot is a collection of command style functions that make Matplotlib work like MATLAB. Each Pyplot function makes some change to a figure. For example, a function creates a figure, a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels, etc.
#
# matplotlib.pyplot is a collection of functions that make matplotlib work like MATLAB. Each pyplot function makes some change to a figure: e.g., creates a figure, creates a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels, etc.
#
# In matplotlib.pyplot various states are preserved across function calls, so that it keeps track of things like the current figure and plotting area, and the plotting functions are directed to the current axes (please note that "axes" here and in most places in the documentation refers to the axes part of a figure and not the strict mathematical term for more than one axis).
#
# ### Data Visualization using Matplotlib:

# %%
import pandas as pd # to work with dataframes
import numpy as np # to do numerical operations
import matplotlib.pyplot as plt # to plot graphs

# '%matplotlib inline' sets the backend of matplotlib to the 'inline' backend: 
#With this backend, the output of plotting commands is displayed inline within frontends like the Jupyter notebook, 
#directly below the code cell that produced it. The resulting plots will then also be stored in the notebook document.

# %matplotlib inline

# %%
x=np.arange(1,10)
print(x)
y=x**2
print(y)
# Out:
# [1 2 3 4 5 6 7 8 9]
# [ 1  4  9 16 25 36 49 64 81]

# %% [markdown]
# **Plot function in Matplotlib.pyplot**
# Plot y versus x as lines and/or markers.
# plot([x], y, [fmt], *, data=None, **kwargs)
# The coordinates of the points or line nodes are given by x, y.
# The optional parameter fmt is a convenient way for defining basic formatting like color, marker and linestyle.
# Refer: https://matplotlib.org/3.3.3/api/_as_gen/matplotlib.pyplot.plot.html

# %%
# Plot y versus x as lines and/or markers.
plt.plot(x,y) # values are plotted using plot function

# %% [markdown]
# **pyplot.subplot()**
# pyplot.subplots creates a figure and a grid of subplots with a single call, while providing reasonable control over how the individual plots are created. subplots() without arguments returns a Figure and a single Axes. To obtain side-by-side subplots, pass parameters 1, 2 for one row and two columns. e.g. plt.subplots(1, 2). Refer https://matplotlib.org/3.3.3/gallery/subplots_axes_and_figures/subplots_demo.html

# %%
plt.subplot(2,2,1)# Create subplot of 2x2 and plot 1st subplot in this 2x2 plot
plt.plot(x,y,'ro') # x and y values are ploted with red color
plt.xlabel('x')# x axis is labelled
plt.ylabel('y')# y axis is labelled
# Out:
# Text(0, 0.5, 'y')

# %%
plt.subplot(2,2,1)# Create subplot of 2x2 and plot 1st subplot in this 2x2 plot
plt.plot(x,y,'ro') # x and y values are ploted with red color
plt.xlabel('x')# x axis is labelled
plt.ylabel('y')# y axis is labelledplt.subplot(2,2,2) #Create subplot of 2x2 and plot 2nd subplot in this 2x2 plot
plt.subplot(2,2,2)
plt.plot(x,y,'yellow') ## x and y values are ploted with yellow color
plt.xlabel('x')
plt.ylabel('y')
plt.subplot(2,2,3)
plt.plot(x,y,'g') # observe the output
plt.xlabel('x')
plt.ylabel('y')
plt.subplot(2,2,4) # observe the output
plt.plot(x,y,'b--')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
# Read Toyota.csv file using Pandas and store it in 'cars'
cars=pd.read_csv('C:/Users/Swift 3/AppData/Local/Programs/Python/Python38/toyota.csv')

# %%
# Display first 5 rows of DataFrame cars

# %%
# Check shape of cars dataframe

# %%
# Get information of each column of cars

# %%
#create copy of cars and name it as cars1

# %%
# Display first 5 rows of cars1

# %%
# detect and count null values or missing values in each column, isnull() can also be used in place of isna()

# %% [markdown]
# **dropna() removes missing values from dataframe**
#
# Syntax-- DataFrame.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
#
# Parameters:
# axis{0 or ‘index’, 1 or ‘columns’}, default 0.
# how{‘any’, ‘all’}, default ‘any’
# Determine if row or column is removed from DataFrame, when we have at least one NA or all NA.
# ‘any’ : If any NA values are present, drop that row or column.
# ‘all’ : If all values are NA, drop that row or column.
#
# inplace:  bool, default False
# If True, do operation inplace and return None.

# %%
cars.dropna(axis=0,inplace=True)

# %%
# Check shape of the cars dataset again

# %% [markdown]
# **Scatter plots:**
# The scatter() function makes a scatter plot with (optional) size and color arguments. A scatter plot of y vs. x with varying marker size and/or color. Refer: https://matplotlib.org/3.3.3/api/_as_gen/matplotlib.pyplot.scatter.html#matplotlib.pyplot.scatter

# %%
# Scatterplot
plt.scatter(cars['Age'],cars['Price'],c='blue') # x,y and color is specified
plt.xlabel('Age') # label on x axis
plt.ylabel('Price') # label on y axis
plt.title('Scatterplot of Price vs Age') # Title of the plot
plt.show() # Display plot
plt.savefig('cars price for Age.png') # save plot as figure

# %% [markdown]
# **Bar plots:** The bar() function makes a bar plot with (optional) size and color arguments. A bar plot of y vs. x with varying marker size and/or color. Refer: https://matplotlib.org/3.3.3/api/_as_gen/matplotlib.pyplot.bar.html#matplotlib.pyplot.bar
# To plot a horizontal barchar we can use barh command instead of bar.

# %%
plt.bar(cars['HP'],cars['Price'])
plt.xlabel('HP')
plt.ylabel('Price')
plt.title('Scatterplot of Price vs FuelType')
plt.show()

# %% [markdown]
# **Histogram using pyplot:**
# The hist() function automatically generates histograms and returns the bin counts or probabilities. Multiple data can be provided via x as a list of datasets of potentially different length ([x0, x1, ...]), or as a 2-D ndarray in which each column is a dataset.
#
# Refer: https://matplotlib.org/3.3.3/api/_as_gen/matplotlib.pyplot.hist.html#matplotlib.pyplot.hist

# %%
# Histogram: to plot frequency of numerical attribute
plt.hist(cars['Age'],bins=4)
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('frequency')
plt.show()

# %%
data=[np.random.normal(0,std,60) for std in range (1,4)]
print(data)
# Out:
# [array([-0.78721482, -0.92204251, -0.6562242 ,  0.01247122, -0.84640973,
#        -1.69153608,  0.67700265,  1.79217161,  0.33901004, -2.0749309 ,
#         0.52851334,  0.96819266,  1.38644649, -0.08284897, -0.71222838,
#        -0.71069134, -0.69882986, -2.31633697,  0.31938821,  0.66831391,
#        -1.10224948, -0.14034278, -0.5284895 , -0.56184283,  0.71474591,
#         0.2197655 , -0.26622338, -0.37966218, -0.18146674, -0.37538935,
#        -1.97718891, -0.59870126, -0.18418371, -1.17941384, -0.65642761,
#         0.34881732, -0.55448744,  0.75720789,  0.04800587,  0.7337249 ,
#         0.71530919,  1.24442423,  0.20459198,  1.17514373, -0.15308624,
#        -0.07951335,  0.19444229, -0.85468034, -1.80683112,  0.13501531,
#        -0.90651815, -1.24085386, -0.23719446, -1.28750757, -0.2913596 ,
#        -1.67577801,  0.03449986,  2.13287918, -0.9173941 ,  1.03676919]), array([-4.15073864e-01, -1.28174380e+00,  3.50315318e+00, -1.69777485e-01,
# ...

# %%
print(len(data))
# Out:
# 3

# %% [markdown]
# **Boxplot using Pyplot:**
# A boxplot is a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile (Q1), median, third quartile (Q3), and “maximum”). It can tell you about your outliers and what their values are. It can also tell you if your data is symmetrical, how tightly your data is grouped, and if and how your data is skewed. A boxplot is a graph that gives you a good indication of how the values in the data are spread out. Although boxplots may seem primitive in comparison to a histogram or density plot, they have the advantage of taking up less space, which is useful when comparing distributions between many groups or datasets.
#
# One of the most common ways to analyze the relationship between a categorical feature and a continuous feature is to plot a boxplot. The boxplot is a simple way of representing statistical data on a plot in which a rectangle is drawn to represent the second and third quartiles, usually with a vertical line inside to indicate the median value. The lower and upper quartiles are shown as horizontal lines at either side of the rectangle.
# ![image.png](attachment:image.png)
#
# More information can be obtained in this article: https://towardsdatascience.com/understanding-boxplots-5e2df7bcbd51

# %%
plt.boxplot(data,vert=True,patch_artist=True);

# %% [markdown]
# Above discussed plots can also be drawn with the help of another python library calls as 'Seaborn'. Let us see how we can plot different types of graphs using seaborn.
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.Seaborn is a library for making statistical graphics in Python. It builds on top of matplotlib and integrates closely with pandas data structures.
#
# Seaborn helps you explore and understand your data. Its plotting functions operate on dataframes and arrays containing whole datasets and internally perform the necessary semantic mapping and statistical aggregation to produce informative plots. Its dataset-oriented, declarative API lets you focus on what the different elements of your plots mean, rather than on the details of how to draw them. Documentation of Seaborn can be obtained at https://seaborn.pydata.org/introduction.html

# %%
# scatterplot using seaborn
import seaborn as sns
sns.scatterplot(data=cars,x=cars['Age'],y=cars['Price'],hue=cars['FuelType'],size=cars['FuelType'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Price'>

# %% [markdown]
# **Visualizing Distributions of data using Seaborn**
# An early step in any effort to analyze or model data should be to understand how the variables are distributed. Techniques for distribution visualization can provide quick answers to many important questions. What range do the observations cover? What is their central tendency? Are they heavily skewed in one direction? Is there evidence for bimodality? Are there significant outliers? Do the answers to these questions vary across subsets defined by other variables?
# Perhaps the most common approach to visualizing a distribution is the histogram. This is the default approach in displot(), which uses the same underlying code as histplot(). A histogram is a bar plot where the axis representing the data variable is divided into a set of discrete bins and the count of observations falling within each bin is shown using the height of the corresponding bar.

# %%
sns.distplot(cars['Age'],bins=10,norm_hist=False,kde=True)
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# **Countplot in Seaborn**
# Show the counts of observations in each categorical bin using bars.
# A count plot can be thought of as a histogram across a categorical, instead of quantitative, variable. The basic API and options are identical to those for barplot(), so you can compare counts across nested variables.
# Input data can be passed in a variety of formats, including:
# Vectors of data represented as lists, numpy arrays, or pandas Series objects passed directly to the x, y, and/or hue parameters.
# A “long-form” DataFrame, in which case the x, y, and hue variables will determine how the data are plotted.
# A “wide-form” DataFrame, such that each numeric column will be plotted.
# An array or list of vectors.
# In most cases, it is possible to use numpy or Python objects, but pandas objects are preferable because the associated names will be used to annotate the axes. Additionally, you can use Categorical types for the grouping variables to control the order of plot elements.
# This function always treats one of the variables as categorical and draws data at ordinal positions (0, 1, … n) on the relevant axis, even when the data has a numeric or date type.

# %%
sns.countplot(y=cars['FuelType'],data=cars)
# Out:
# <AxesSubplot:xlabel='count', ylabel='FuelType'>

# %%
# Grouped Bar Plot
sns.countplot(x=cars['FuelType'],data=cars,hue=cars['Automatic'])
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='count'>

# %% [markdown]
# **Boxplot using Seaborn**

# %%
sns.boxplot(cars['Price'])
# Out:
# <AxesSubplot:xlabel='Price'>

# %%
sns.boxplot(x=cars['FuelType'],y=cars['Price'])# price for each fueltype
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='Price'>

# %% [markdown]
# ### Exercise
# 1. Write the summary of boxplot obtained above using sns.boxplot(x=cars['FuelType'],y=cars['Price']) command
# 2. Given any dataset,when will you prefer to use boxplot, barplot, scatterplot and histogram?

# %% [markdown]
# ### Observations and Learnings
# (To be written by students)

# %% [markdown]
# ### Conclusion
# (To be written by students)
